# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %cd /content/gdrive/My\ Drive/rebarnet
# !ls
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# /content/gdrive/My Drive/rebarnet
# dataLoader.py  model.py  __pycache__  runner.ipynb  train.py
# experiments    models	 rebar_data   test.py	    utils.py

# %%
# !python train.py
# Out:
# Namespace(batchSize=16, experiment='checkpoint', gpuId=0, imSize=300, imageRoot='./rebar_data/images/', initLR=0.1, nepoch=100, noCuda=False, trainLabelFile='./rebar_data/labels/train.json', valLabelFile='./rebar_data/labels/val.json')
# mkdir: cannot create directory ‘experiments/checkpoint’: File exists
# Image Num: 11
# Image Num: 5
#
#  meow meow meow meow meow ...
#
# Traceback (most recent call last):
#   File "train.py", line 298, in <module>
#     train()
#   File "train.py", line 157, in train
#     for i, dataBatch in enumerate(segTrainLoader ):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 345, in __next__
#     data = self._next_data()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 385, in _next_data
#     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/_utils/fetch.py", line 44, in fetch
# ...
